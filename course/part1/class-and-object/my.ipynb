# %%
car_company = "Toyota"
car_details = {
    'color': 'Red',
    'model': 'Camry',
    'year': 2021,
    'horsepower': 203,
    'price': 25000
}

print(car_company, car_details)
# Out:
# Toyota {'color': 'Red', 'model': 'Camry', 'year': 2021, 'horsepower': 203, 'price': 25000}

# %%
car_company_list = ['Ferrari', 'Lamborghini', 'Porsche']

car_detail_list = [
    {
        'color': 'Red',
        'model': 'SF90',
        'year': 2021,
        'horsepower': 1000,
        'price': 500000
    },
    {
        'color': 'Yellow',
        'model': 'Aventador',
        'year': 2020,
        'horsepower': 759,
        'price': 393695
    },
    {
        'color': 'Black',
        'model': '911 Turbo S',
        'year': 2021,
        'horsepower': 640,
        'price': 203500
    }
]

# %%
del car_company_list[1]
del car_detail_list[1]

print(car_company_list, car_detail_list)
# Out:
# ['Ferrari', 'Porsche'] [{'color': 'Red', 'model': 'SF90', 'year': 2021, 'horsepower': 1000, 'price': 500000}, {'color': 'Black', 'model': '911 Turbo S', 'year': 2021, 'horsepower': 640, 'price': 203500}]

# %% [markdown]
# # 클래스를 써야 하는 이유?

# %%
class Car:
    def __init__(self, company, color, model, year, horsepower, price):
        self.company = company
        self.color = color
        self.model = model
        self.year = year
        self.horsepower = horsepower
        self.price = price
