# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ***
# ## 2. Assigning & Comparison💻
# ***
# #### **`연습예제1`** 💻

# %% [markdown]
# `아래 파이썬 코드의 결과 값을` **`True or False`**  `값을 예상하고 아래 코딩영역에 작성하세요.`
#
# ```python
# x = 15
# y = 25
#
# print(f'x == y : {x == y}')
# print(f'x is y : {x is y}')
#
# # print(f'x value, id : {x}, {hex(id(x))}')
# # print(f'y value, id : {y}, {hex(id(y))}')
# ```

# %% [markdown]
# #### **`코딩영역1`**

# %%
# 코딩 영역

# 예상: False, False

x = 15
y = 25

print(f'x == y : {x == y}')
print(f'x is y : {x is y}')

print(f'x value, id : {x}, {hex(id(x))}')
print(f'y value, id : {y}, {hex(id(y))}')
# Out:
# x == y : False
# x is y : False
# x value, id : 15, 0x1012d2b28
# y value, id : 25, 0x1012d2c68

# %% [markdown]
# ***
# #### **`연습예제2`**

# %% [markdown]
# `아래 파이썬 코드의 결과 값을` **`True or False`**  `값을 예상하고 아래 코딩영역에 작성하세요.`
#
# ```python
# x = ['orange', 'banana', 'apple']
# y = x
#
# print(f'x == y : {x == y}')
# print(f'x is y : {x is y}')
#
# # print(f'x value, id : {x}, {hex(id(x))}')
# # print(f'y value, id : {y}, {hex(id(y))}')
# ```

# %% [markdown]
# #### **`코딩영역2`**

# %%
# 코딩 영역

# 예상: True, True 

x = ['orange', 'banana', 'apple']
y = x

print(f'x == y : {x == y}')
print(f'x is y : {x is y}')

print(f'x value, id : {x}, {hex(id(x))}')
print(f'y value, id : {y}, {hex(id(y))}')
# Out:
# x == y : True
# x is y : True
# x value, id : ['orange', 'banana', 'apple'], 0x104def980
# y value, id : ['orange', 'banana', 'apple'], 0x104def980

# %% [markdown]
# ***
# #### **`연습예제3`**

# %% [markdown]
# `아래 파이썬 코드의 결과 값을` **`True or False`**  `값을 예상하고 아래 코딩영역에 작성하세요.`
#
# ```python
# x = ['orange', 'banana', 'apple']
# y = ['orange', 'banana', 'apple']
#
# print(f'x == y : {x == y}')
# print(f'x is y : {x is y}')
#
# # print(f'x value, id : {x}, {hex(id(x))}')
# # print(f'y value, id : {y}, {hex(id(y))}')
# ```

# %% [markdown]
# #### **`코딩영역3`**

# %%
# 코딩 영역

# 예상: True, False

x = ['orange', 'banana', 'apple']
y = ['orange', 'banana', 'apple']

print(f'x == y : {x == y}')
print(f'x is y : {x is y}')

# print(f'x value, id : {x}, {hex(id(x))}')
# print(f'y value, id : {y}, {hex(id(y))}')
# Out:
# x == y : True
# x is y : False

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # is , not is -> 참조, 객체(same object, 오브젝트)비교
# # == , != -> 값 비교
# # 값, 참조가 같은 비교는 is 사용(중요)
#
# ```
# </div>
# </details>

# %% [markdown]
# ***
